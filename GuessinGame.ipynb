# %%
# Tässä loopin kanssa
name = "Joonas"
guess = ""
while guess != name:
    guess = input("Guess the name, you have unlimited number of tries: ")
print("Congratulations!")
# Out:
# Congratulations!

# %%
# Guessing game tehtävä, tässä ilman loop structurea
name = "Joonas"
guess = input("Guess the name: ")
if guess == name:
    print("Congratulation")
else:
    print("Wrong!")
# Out:
# Wrong!
