# %%
print("Printer app")
creator = "Joonas Koivunen"
print("This app is made by: " + creator)
number1 = 15
number2 = 20
multiplication = number1 * number2
addition = number1 + number2
division = number1 / number2
subtraction = number1 - number2
print(number1) #print number1
print(f"The value of number1 is {number1}")
print(f"The value of number2 is {number2}")
print(multiplication)
print(addition)
print(division)
print(subtraction)
# Out:
# Printer app
# This app is made by: Joonas Koivunen
# 15
# The value of number1 is 15
# The value of number2 is 20
# 300
# 35
# 0.75
# -5
